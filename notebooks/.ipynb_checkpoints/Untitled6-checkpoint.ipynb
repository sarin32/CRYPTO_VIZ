# %%
import requests
sentiment_index = requests.get('http://api.senticrypt.com/v1/history/index.json').json()

# %%
sentiment_data = []

# %%
start = sentiment_index.index('bitcoin-2021-06-05_22.json')
stop = sentiment_index.index('bitcoin-2021-08-13_20.json')

for t_stamp in sentiment_index[start:stop]:
    date_str = t_stamp[8:21]
    print(date_str)
    mean = requests.get('http://api.senticrypt.com/v1/history/' + t_stamp).json()[0]['mean']

    sentiment_data.append([date_str, mean])
# Out:
# 2021-06-05_22
# 2021-06-05_23
# 2021-06-06_00
# 2021-06-06_01
# 2021-06-06_02
# 2021-06-06_03
# 2021-06-06_04
# 2021-06-06_05
# 2021-06-06_06
# 2021-06-06_07
# 2021-06-06_08
# 2021-06-06_09
# 2021-06-06_10
# 2021-06-06_11
# 2021-06-06_12
# 2021-06-06_13
# 2021-06-06_14
# 2021-06-06_15
# 2021-06-06_16
# 2021-06-06_17
# ---------------------------------------------------------------------------
# ConnectionAbortedError                    Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python39\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\urllib3\util\connection.py:95, in create_connection(address, timeout, source_address, socket_options)
#      94 if err is not None:
# ---> 95     raise err
# ...

# %%
sentiment_data
# Out:
# [['2021-05-13_20', 0.23],
#  ['2021-05-13_21', 0.2],
#  ['2021-05-13_22', 0.27],
#  ['2021-05-13_23', 0.1],
#  ['2021-05-14_00', 0.11],
#  ['2021-05-14_01', 0.11],
#  ['2021-05-14_02', 0.13],
#  ['2021-05-14_03', 0.13],
#  ['2021-05-14_04', 0.14],
#  ['2021-05-14_05', 0.14],
#  ['2021-05-14_06', 0.15],
#  ['2021-05-14_07', 0.16],
#  ['2021-05-14_08', 0.16],
#  ['2021-05-14_09', 0.15],
#  ['2021-05-14_10', 0.15],
#  ['2021-05-14_11', 0.12],
#  ['2021-05-14_12', 0.13],
#  ['2021-05-14_13', 0.12],
#  ['2021-05-14_14', 0.14],
#  ['2021-05-14_15', 0.12],
#  ['2021-05-14_16', 0.11],
#  ['2021-05-14_17', 0.14],
#  ['2021-05-14_18', 0.09],
#  ['2021-05-14_19', 0.13],
#  ['2021-05-14_20', 0.13],
#  ['2021-05-14_21', 0.16],
#  ['2021-05-14_22', 0.16],
#  ['2021-05-14_23', 0.16],
#  ['2021-05-15_00', 0.17],
#  ['2021-05-15_01', 0.14],
#  ['2021-05-15_02', 0.15],
#  ['2021-05-15_03', 0.17],
#  ['2021-05-15_04', 0.17],
#  ['2021-05-15_05', 0.19],
#  ['2021-05-15_06', 0.2],
# ...

# %%
import csv
with open('data6.csv', 'w') as f:
      
    # using csv.writer method from CSV package
    write = csv.writer(f)
    write.writerows(sentiment_data)
