# %% [markdown]
# #### function to extract data from binance api

# %%
from binance.client import Client
import pandas as pd
def data_extract(sym, start, end):
    client = Client('API_KEY', 'SECRET_KEY')
    if end =="":
        cryptocurrency = client.get_historical_klines(symbol=sym, interval=Client.KLINE_INTERVAL_1HOUR, start_str=start)
    else:
        cryptocurrency = client.get_historical_klines(symbol=sym, interval=Client.KLINE_INTERVAL_1HOUR, start_str=start, end_str=end)
    cryptocurrency = pd.DataFrame(cryptocurrency, columns=['Open time', 'Open', 'High', 'Low', 'Close', 'Volume', 'Close time', 'Quote asset volume', 'Number of trades', 'Taker buy base asset volume', 'Taker buy quote asset volume', 'Ignore'])
    return cryptocurrency

# %%
symbol = 'BTCUSDT'
start = '2020-02-13 20:00:00'
end = '2022-05-30 19:00:00'
btcDf = data_extract(symbol,start,end)

# %%
btcDf
# Out:
#            Open time            Open            High             Low  \
# 0      1581624000000  10251.15000000  10265.00000000  10208.14000000
# 1      1581627600000  10226.50000000  10228.95000000  10181.88000000
# 2      1581631200000  10189.86000000  10240.26000000  10185.03000000
# 3      1581634800000  10224.00000000  10252.79000000  10207.02000000
# 4      1581638400000  10227.78000000  10242.79000000  10178.27000000
# ...              ...             ...             ...             ...
# 20054  1653922800000  30467.42000000  30679.00000000  30450.00000000
# 20055  1653926400000  30634.08000000  30714.22000000  30566.54000000
# 20056  1653930000000  30622.04000000  30786.49000000  30582.70000000
# 20057  1653933600000  30706.85000000  30720.00000000  30643.04000000
# 20058  1653937200000  30674.79000000  30878.10000000  30586.27000000
#
#                 Close         Volume     Close time  Quote asset volume  \
# ...

# %% [markdown]
# #### save dataset to csv

# %%
btcDf.to_csv('bitcoin.csv',index=False)
